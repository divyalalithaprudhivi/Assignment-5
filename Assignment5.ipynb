# %%
data=pd.read_csv("US_Baby_Names_right.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c8c33d8d153c> in <module>()
# ----> 1 data=pd.read_csv("US_Baby_Names_right.csv")
#
# NameError: name 'pd' is not defined

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("US_Baby_Names_right.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %% [markdown]
# 1. Delete unnamed columns

# %%
data.loc[:, ~data.columns.str.contains('^Unnamed')]
# Out:
#               Id       Name  Year Gender State  Count
# 0          11350       Emma  2004      F    AK     62
# 1          11351    Madison  2004      F    AK     48
# 2          11352     Hannah  2004      F    AK     46
# 3          11353      Grace  2004      F    AK     44
# 4          11354      Emily  2004      F    AK     41
# 5          11355    Abigail  2004      F    AK     37
# 6          11356     Olivia  2004      F    AK     33
# 7          11357   Isabella  2004      F    AK     30
# 8          11358     Alyssa  2004      F    AK     29
# 9          11359     Sophia  2004      F    AK     28
# 10         11360     Alexis  2004      F    AK     27
# 11         11361  Elizabeth  2004      F    AK     27
# 12         11362     Hailey  2004      F    AK     27
# 13         11363       Anna  2004      F    AK     26
# 14         11364    Natalie  2004      F    AK     25
# 15         11365      Sarah  2004      F    AK     25
# ...

# %% [markdown]
# 2. Show the distribution of male and female

# %%
import matplotlib.pyplot as plt
var = data.groupby('Gender').Count.sum() 
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.set_xlabel('Gender')
ax1.set_ylabel('count')
ax1.set_title("Gender wise count")
var.plot(kind='bar')

# %% [markdown]
# 3. Show the top 5 most preferred names

# %% [markdown]
# 4. What is the median name occurence in the dataset

# %%
data['Name'] = abs(data['Count'] - data['Count'].median())

# %%
data['Name']
# Out:
# 0          51.0
# 1          37.0
# 2          35.0
# 3          33.0
# 4          30.0
# 5          26.0
# 6          22.0
# 7          19.0
# 8          18.0
# 9          17.0
# 10         16.0
# 11         16.0
# 12         16.0
# 13         15.0
# 14         14.0
# 15         14.0
# 16         14.0
# 17         12.0
# 18         11.0
# 19         10.0
# 20         10.0
# 21         10.0
# 22          9.0
# 23          9.0
# 24          9.0
# 25          8.0
# 26          7.0
# 27          7.0
# 28          7.0
# 29          6.0
#            ...
# 1016365     6.0
# 1016366     6.0
# 1016367     6.0
# 1016368     6.0
# 1016369     6.0
# 1016370     6.0
# 1016371     6.0
# 1016372     6.0
# 1016373     6.0
# 1016374     6.0
# 1016375     6.0
# 1016376     6.0
# 1016377     6.0
# 1016378     6.0
# 1016379     6.0
# 1016380     6.0
# 1016381     6.0
# 1016382     6.0
# 1016383     6.0
# 1016384     6.0
# 1016385     6.0
# 1016386     6.0
# 1016387     6.0
# 1016388     6.0
# ...

# %%
 data[data.Count ==data.Count.median()]
# Out:
#          Unnamed: 0       Id       Name  Year Gender State  Count
# 0             11349    11350       Emma  2004      F    AK    3.0
# 1             11350    11351    Madison  2004      F    AK    3.0
# 2             11351    11352     Hannah  2004      F    AK    3.0
# 3             11352    11353      Grace  2004      F    AK    3.0
# 4             11353    11354      Emily  2004      F    AK    3.0
# 5             11354    11355    Abigail  2004      F    AK    3.0
# 6             11355    11356     Olivia  2004      F    AK    3.0
# 7             11356    11357   Isabella  2004      F    AK    3.0
# 8             11357    11358     Alyssa  2004      F    AK    3.0
# 9             11358    11359     Sophia  2004      F    AK    3.0
# 10            11359    11360     Alexis  2004      F    AK    3.0
# 11            11360    11361  Elizabeth  2004      F    AK    3.0
# 12            11361    11362     Hailey  2004      F    AK    3.0
# ...

# %% [markdown]
# 5. Distribution of male and female born count by states

# %%
import matplotlib.pyplot as plt
var = data.groupby(['Gender','State']).describe() 
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
ax1.set_xlabel('Gender')
ax1.set_ylabel('State')
ax1.set_title("GS")
var.plot(kind='bar')

# %%
var = data.groupby(['Gender','State']).describe()

# %%
var
# Out:
#                 Count                                                       \
#                 count       mean         std  min  25%   50%   75%     max
# Gender State
# F      AK      2404.0  10.919301    8.159519  5.0  6.0   8.0  13.0    62.0
#        AL      9878.0  21.796720   34.348342  5.0  6.0  10.0  21.0   403.0
#        AR      7171.0  18.088412   23.925343  5.0  6.0  10.0  19.0   281.0
#        AZ     14518.0  25.386899   43.385838  5.0  7.0  11.0  23.0   604.0
#        CA     45144.0  53.474725  164.342504  5.0  7.0  12.0  32.0  3634.0
#        CO     11424.0  22.829569   34.731560  5.0  6.0  10.0  23.0   349.0
#        CT      6575.0  21.498099   31.547791  5.0  6.0  10.0  22.0   309.0
#        DC      3053.0  11.554537    8.260903  5.0  6.0   8.0  14.0    58.0
#        DE      2549.0  12.284033   10.549546  5.0  6.0   8.0  14.0    73.0
#        FL     25781.0  35.507622   87.603032  5.0  6.0  11.0  27.0  1835.0
# ...

# %% [markdown]
# # Task2

# %% [markdown]
# We have the min and max temperatures in a city In India for each months of the year. We
# would like to find a function to describe this and show it graphically, the dataset given below.
# Task:
# 1. fitting it to the periodic function
# 2. plot the fit
# Data
# Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
# Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %%
import numpy as np


temp_max = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
temp_min = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])

import matplotlib.pyplot as plt
months = np.arange(12)
plt.plot(months, temp_max, 'ro')
plt.plot(months, temp_min, 'bo')
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')
# Out:
# Text(0,0.5,'Temperature ($^\\circ$C)')

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize
def yearly_temps(times, avg, ampl, time_offset):
    return (avg + ampl * np.cos((times + time_offset) * 2 * np.pi / times.max()))
res_max, cov_max = optimize.curve_fit(yearly_temps, months,temp_max,[30,49,25])
res_min, cov_min = optimize.curve_fit(yearly_temps, months,temp_min,[21,32,17])
days = np.linspace(0, 12, num=365)
plt.figure()
plt.plot(months, temp_max, 'ro')
plt.plot(days, yearly_temps(days, *res_max), 'r-')
plt.plot(months, temp_min, 'bo')
plt.plot(days, yearly_temps(days, *res_min), 'b-')
plt.xlabel('Month')
plt.ylabel('Temperature ($^\circ$C)')
plt.show()
